# %%
import pandas as pd
import numpy as np
ad = pd.read_excel('Desktop/NZ_Admin_JOBS.xlsx')
df = pd.DataFrame(ad)
print(df)
# Out:
#                                        字段1  \
# 0                            Administrator
# 1                             Receptionist
# 2             Prosecutions Support Officer
# 3     Early Childhood Centre Administrator
# 4           Business Support Administrator
# ...                                    ...
# 2703                   Key Account Manager
# 2704                   Executive Assistant
# 2705                Temporary Office Roles
# 2706                Temporary Office Roles
# 2707                   Executive Assistant
#
#                                                字段1_link  \
# 0     https://www.seek.co.nz/job/50582301?type=promo...
# 1     https://www.seek.co.nz/job/50620889?type=promo...
# 2     https://www.seek.co.nz/job/50622169?type=stand...
# 3     https://www.seek.co.nz/job/50639620?type=stand...
# 4     https://www.seek.co.nz/job/50622432?type=stand...
# ...                                                 ...
# ...

# %%
print(df.dtypes)
# Out:
# 字段1         object
# 字段1_link    object
# 字段2         object
# 字段3         object
# 字段4         object
# 字段5         object
# dtype: object

# %%
print(df.columns)
# Out:
# Index(['字段1', '字段1_link', '字段2', '字段3', '字段4', '字段5'], dtype='object')

# %%
df['字段1'] = df['字段1'].str.title()

# %%
df['字段1'].head(10)
# Out:
# 0                           Administrator
# 1                            Receptionist
# 2            Prosecutions Support Officer
# 3    Early Childhood Centre Administrator
# 4          Business Support Administrator
# 5                         Support Officer
# 6                         Support Officer
# 7                    Office Administrator
# 8                    Office Administrator
# 9                  Administration Officer
# Name: 字段1, dtype: object

# %%
df['字段2']
# Out:
# 0                                            NaN
# 1                           Avenues Orthodontics
# 2                             New Zealand Police
# 3       Kew Pacific Island Early Learning Centre
# 4                                            NaN
#                           ...
# 2703                       Hays Talent Solutions
# 2704                      one eighty recruitment
# 2705                       Asset Recruitment Ltd
# 2706                       Asset Recruitment Ltd
# 2707                      Alpha Recruitment - NZ
# Name: 字段2, Length: 2708, dtype: object

# %%
df.fillna('Private Advertiser')
df
# Out:
#                                        字段1  \
# 0                            Administrator
# 1                             Receptionist
# 2             Prosecutions Support Officer
# 3     Early Childhood Centre Administrator
# 4           Business Support Administrator
# ...                                    ...
# 2703                   Key Account Manager
# 2704                   Executive Assistant
# 2705                Temporary Office Roles
# 2706                Temporary Office Roles
# 2707                   Executive Assistant
#
#                                                字段1_link  \
# 0     https://www.seek.co.nz/job/50582301?type=promo...
# 1     https://www.seek.co.nz/job/50620889?type=promo...
# 2     https://www.seek.co.nz/job/50622169?type=stand...
# 3     https://www.seek.co.nz/job/50639620?type=stand...
# 4     https://www.seek.co.nz/job/50622432?type=stand...
# ...                                                 ...
# ...

# %%
print(df.fillna('Private Advertiser'))
# Out:
#                                        字段1  \
# 0                            Administrator
# 1                             Receptionist
# 2             Prosecutions Support Officer
# 3     Early Childhood Centre Administrator
# 4           Business Support Administrator
# ...                                    ...
# 2703                   Key Account Manager
# 2704                   Executive Assistant
# 2705                Temporary Office Roles
# 2706                Temporary Office Roles
# 2707                   Executive Assistant
#
#                                                字段1_link  \
# 0     https://www.seek.co.nz/job/50582301?type=promo...
# 1     https://www.seek.co.nz/job/50620889?type=promo...
# 2     https://www.seek.co.nz/job/50622169?type=stand...
# 3     https://www.seek.co.nz/job/50639620?type=stand...
# 4     https://www.seek.co.nz/job/50622432?type=stand...
# ...                                                 ...
# ...

# %%
df['字段2']
# Out:
# 0                                            NaN
# 1                           Avenues Orthodontics
# 2                             New Zealand Police
# 3       Kew Pacific Island Early Learning Centre
# 4                                            NaN
#                           ...
# 2703                       Hays Talent Solutions
# 2704                      one eighty recruitment
# 2705                       Asset Recruitment Ltd
# 2706                       Asset Recruitment Ltd
# 2707                      Alpha Recruitment - NZ
# Name: 字段2, Length: 2708, dtype: object

# %%
df.fillna(('Private Advertiser'),inplace = True)
df['字段2']
# Out:
# 0                             Private Advertiser
# 1                           Avenues Orthodontics
# 2                             New Zealand Police
# 3       Kew Pacific Island Early Learning Centre
# 4                             Private Advertiser
#                           ...
# 2703                       Hays Talent Solutions
# 2704                      one eighty recruitment
# 2705                       Asset Recruitment Ltd
# 2706                       Asset Recruitment Ltd
# 2707                      Alpha Recruitment - NZ
# Name: 字段2, Length: 2708, dtype: object

# %%
new = df['字段3'].str.split('area',expand=True)
new
# Out:
#                                          0  \
# 0     location: Bay of PlentyBay of Plenty
# 1     location: Bay of PlentyBay of Plenty
# 2               location: AucklandAuckland
# 3             location: SouthlandSouthland
# 4           location: CanterburyCanterbury
# ...                                    ...
# 2703            location: AucklandAuckland
# 2704        location: WellingtonWellington
# 2705              location: WaikatoWaikato
# 2706              location: WaikatoWaikato
# 2707        location: WellingtonWellington
#
#                                                       1
# 0                                    : TaurangaTauranga
# 1                                    : TaurangaTauranga
# 2                                                  None
# 3                            : InvercargillInvercargill
# 4                            : ChristchurchChristchurch
# ...                                                 ...
# ...

# %%
df['Location'] = new[0]
df['Area'] = new[1]
df
# Out:
#                                        字段1  \
# 0                            Administrator
# 1                             Receptionist
# 2             Prosecutions Support Officer
# 3     Early Childhood Centre Administrator
# 4           Business Support Administrator
# ...                                    ...
# 2703                   Key Account Manager
# 2704                   Executive Assistant
# 2705                Temporary Office Roles
# 2706                Temporary Office Roles
# 2707                   Executive Assistant
#
#                                                字段1_link  \
# 0     https://www.seek.co.nz/job/50582301?type=promo...
# 1     https://www.seek.co.nz/job/50620889?type=promo...
# 2     https://www.seek.co.nz/job/50622169?type=stand...
# 3     https://www.seek.co.nz/job/50639620?type=stand...
# 4     https://www.seek.co.nz/job/50622432?type=stand...
# ...                                                 ...
# ...

# %%
new2 = df['Location'].str.split(': ',expand=True)
new2
# Out:
#              0                           1
# 0     location  Bay of PlentyBay of Plenty
# 1     location  Bay of PlentyBay of Plenty
# 2     location            AucklandAuckland
# 3     location          SouthlandSouthland
# 4     location        CanterburyCanterbury
# ...        ...                         ...
# 2703  location            AucklandAuckland
# 2704  location        WellingtonWellington
# 2705  location              WaikatoWaikato
# 2706  location              WaikatoWaikato
# 2707  location        WellingtonWellington
#
# [2708 rows x 2 columns]

# %%
df['Location'] = new2[1]
df.drop(columns = ['字段3'], inplace = True)
df
# Out:
#                                        字段1  \
# 0                            Administrator
# 1                             Receptionist
# 2             Prosecutions Support Officer
# 3     Early Childhood Centre Administrator
# 4           Business Support Administrator
# ...                                    ...
# 2703                   Key Account Manager
# 2704                   Executive Assistant
# 2705                Temporary Office Roles
# 2706                Temporary Office Roles
# 2707                   Executive Assistant
#
#                                                字段1_link  \
# 0     https://www.seek.co.nz/job/50582301?type=promo...
# 1     https://www.seek.co.nz/job/50620889?type=promo...
# 2     https://www.seek.co.nz/job/50622169?type=stand...
# 3     https://www.seek.co.nz/job/50639620?type=stand...
# 4     https://www.seek.co.nz/job/50622432?type=stand...
# ...                                                 ...
# ...

# %%
df['Area'] = df['Area'].str.replace(': ','')
df
# Out:
#                                        字段1  \
# 0                            Administrator
# 1                             Receptionist
# 2             Prosecutions Support Officer
# 3     Early Childhood Centre Administrator
# 4           Business Support Administrator
# ...                                    ...
# 2703                   Key Account Manager
# 2704                   Executive Assistant
# 2705                Temporary Office Roles
# 2706                Temporary Office Roles
# 2707                   Executive Assistant
#
#                                                字段1_link  \
# 0     https://www.seek.co.nz/job/50582301?type=promo...
# 1     https://www.seek.co.nz/job/50620889?type=promo...
# 2     https://www.seek.co.nz/job/50622169?type=stand...
# 3     https://www.seek.co.nz/job/50639620?type=stand...
# 4     https://www.seek.co.nz/job/50622432?type=stand...
# ...                                                 ...
# ...

# %%
a = df['字段4'].str.extract('(\d+)')
df['Released(days ago)'] = a
df
# Out:
#                                        字段1  \
# 0                            Administrator
# 1                             Receptionist
# 2             Prosecutions Support Officer
# 3     Early Childhood Centre Administrator
# 4           Business Support Administrator
# ...                                    ...
# 2703                   Key Account Manager
# 2704                   Executive Assistant
# 2705                Temporary Office Roles
# 2706                Temporary Office Roles
# 2707                   Executive Assistant
#
#                                                字段1_link  \
# 0     https://www.seek.co.nz/job/50582301?type=promo...
# 1     https://www.seek.co.nz/job/50620889?type=promo...
# 2     https://www.seek.co.nz/job/50622169?type=stand...
# 3     https://www.seek.co.nz/job/50639620?type=stand...
# 4     https://www.seek.co.nz/job/50622432?type=stand...
# ...                                                 ...
# ...

# %%
df.drop(columns = ['字段4'], inplace = True)
df
# Out:
#                                        字段1  \
# 0                            Administrator
# 1                             Receptionist
# 2             Prosecutions Support Officer
# 3     Early Childhood Centre Administrator
# 4           Business Support Administrator
# ...                                    ...
# 2703                   Key Account Manager
# 2704                   Executive Assistant
# 2705                Temporary Office Roles
# 2706                Temporary Office Roles
# 2707                   Executive Assistant
#
#                                                字段1_link  \
# 0     https://www.seek.co.nz/job/50582301?type=promo...
# 1     https://www.seek.co.nz/job/50620889?type=promo...
# 2     https://www.seek.co.nz/job/50622169?type=stand...
# 3     https://www.seek.co.nz/job/50639620?type=stand...
# 4     https://www.seek.co.nz/job/50622432?type=stand...
# ...                                                 ...
# ...

# %%
new3 = df['字段5'].str.split('subClassification: ',expand = True)
df['Classification'] = new3[0]
df['subClassification'] = new3[1]
df
# Out:
#                                        字段1  \
# 0                            Administrator
# 1                             Receptionist
# 2             Prosecutions Support Officer
# 3     Early Childhood Centre Administrator
# 4           Business Support Administrator
# ...                                    ...
# 2703                   Key Account Manager
# 2704                   Executive Assistant
# 2705                Temporary Office Roles
# 2706                Temporary Office Roles
# 2707                   Executive Assistant
#
#                                                字段1_link  \
# 0     https://www.seek.co.nz/job/50582301?type=promo...
# 1     https://www.seek.co.nz/job/50620889?type=promo...
# 2     https://www.seek.co.nz/job/50622169?type=stand...
# 3     https://www.seek.co.nz/job/50639620?type=stand...
# 4     https://www.seek.co.nz/job/50622432?type=stand...
# ...                                                 ...
# ...

# %%
df.drop(columns = ['字段5'], inplace = True)
df
# Out:
#                                        字段1  \
# 0                            Administrator
# 1                             Receptionist
# 2             Prosecutions Support Officer
# 3     Early Childhood Centre Administrator
# 4           Business Support Administrator
# ...                                    ...
# 2703                   Key Account Manager
# 2704                   Executive Assistant
# 2705                Temporary Office Roles
# 2706                Temporary Office Roles
# 2707                   Executive Assistant
#
#                                                字段1_link  \
# 0     https://www.seek.co.nz/job/50582301?type=promo...
# 1     https://www.seek.co.nz/job/50620889?type=promo...
# 2     https://www.seek.co.nz/job/50622169?type=stand...
# 3     https://www.seek.co.nz/job/50639620?type=stand...
# 4     https://www.seek.co.nz/job/50622432?type=stand...
# ...                                                 ...
# ...

# %%
df['Classification'] = df['Classification'].str.replace('classification: ','')
df
# Out:
#                                        字段1  \
# 0                            Administrator
# 1                             Receptionist
# 2             Prosecutions Support Officer
# 3     Early Childhood Centre Administrator
# 4           Business Support Administrator
# ...                                    ...
# 2703                   Key Account Manager
# 2704                   Executive Assistant
# 2705                Temporary Office Roles
# 2706                Temporary Office Roles
# 2707                   Executive Assistant
#
#                                                字段1_link  \
# 0     https://www.seek.co.nz/job/50582301?type=promo...
# 1     https://www.seek.co.nz/job/50620889?type=promo...
# 2     https://www.seek.co.nz/job/50622169?type=stand...
# 3     https://www.seek.co.nz/job/50639620?type=stand...
# 4     https://www.seek.co.nz/job/50622432?type=stand...
# ...                                                 ...
# ...

# %%
df.rename(columns = {'字段1':'Title','字段1_link':'Link','字段2':'Advertiser'})
# Out:
#                                      Title  \
# 0                            Administrator
# 1                             Receptionist
# 2             Prosecutions Support Officer
# 3     Early Childhood Centre Administrator
# 4           Business Support Administrator
# ...                                    ...
# 2703                   Key Account Manager
# 2704                   Executive Assistant
# 2705                Temporary Office Roles
# 2706                Temporary Office Roles
# 2707                   Executive Assistant
#
#                                                    Link  \
# 0     https://www.seek.co.nz/job/50582301?type=promo...
# 1     https://www.seek.co.nz/job/50620889?type=promo...
# 2     https://www.seek.co.nz/job/50622169?type=stand...
# 3     https://www.seek.co.nz/job/50639620?type=stand...
# 4     https://www.seek.co.nz/job/50622432?type=stand...
# ...                                                 ...
# ...

# %%
df.to_excel('Desktop/NZJOBS.xlsx')
print('yes')
# Out:
# yes

# %%
df
# Out:
#                                        字段1  \
# 0                            Administrator
# 1                             Receptionist
# 2             Prosecutions Support Officer
# 3     Early Childhood Centre Administrator
# 4           Business Support Administrator
# ...                                    ...
# 2703                   Key Account Manager
# 2704                   Executive Assistant
# 2705                Temporary Office Roles
# 2706                Temporary Office Roles
# 2707                   Executive Assistant
#
#                                                字段1_link  \
# 0     https://www.seek.co.nz/job/50582301?type=promo...
# 1     https://www.seek.co.nz/job/50620889?type=promo...
# 2     https://www.seek.co.nz/job/50622169?type=stand...
# 3     https://www.seek.co.nz/job/50639620?type=stand...
# 4     https://www.seek.co.nz/job/50622432?type=stand...
# ...                                                 ...
# ...

# %%
df.rename(columns = {'字段1':'Title','字段1_link':'Link','字段2':'Advertiser'},inplace = True)
df
# Out:
#                                      Title  \
# 0                            Administrator
# 1                             Receptionist
# 2             Prosecutions Support Officer
# 3     Early Childhood Centre Administrator
# 4           Business Support Administrator
# ...                                    ...
# 2703                   Key Account Manager
# 2704                   Executive Assistant
# 2705                Temporary Office Roles
# 2706                Temporary Office Roles
# 2707                   Executive Assistant
#
#                                                    Link  \
# 0     https://www.seek.co.nz/job/50582301?type=promo...
# 1     https://www.seek.co.nz/job/50620889?type=promo...
# 2     https://www.seek.co.nz/job/50622169?type=stand...
# 3     https://www.seek.co.nz/job/50639620?type=stand...
# 4     https://www.seek.co.nz/job/50622432?type=stand...
# ...                                                 ...
# ...

# %%
df.to_excel('Desktop/NZJOBS.xlsx')
print('yes!')
# Out:
# yes!
